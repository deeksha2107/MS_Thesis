# %%
# Installation of all the required libraries
#!pip install accelerate -U  
# Utility to optimize PyTorch models for various hardware
#!pip install transformers[torch]  
# Hugging Face's transformers library with PyTorch support
#!pip install torch          
# PyTorch library
#!pip install openpyxl       
# Library to read/write Excel files
#!pip install scikit-learn

# %%
# Import the necessary libraries
import sklearn
import pickle
import time
import pandas as pd
import matplotlib.pyplot as plt
from numpy import mean
from sklearn.feature_extraction.text import TfidfVectorizer
#performance and evaluation of test data using metrics - accuracy score, confusion matrix, and classification report.
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score,roc_curve,auc
#Classiifers - Logistic Regression, SVC, Random Forest, and Multinomial Naive Bayes, are trained on the training data.
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.neural_network import MLPClassifier  
from sklearn.model_selection import StratifiedKFold, GridSearchCV, KFold, cross_val_score

# %%
#Random Forest Model
# Function to build and evaluate a Random Forest model
def build_model_RF(X_train, y_train, X_test, y_test, name_of_test):
    # Initialization and training a Random Forest model with specified parameters
    start_time = time.time()
    rfc = RandomForestClassifier()
    #parameters
    max_depth = [3, 5, 10, None]
    min_samples_leaf = [1, 5, 10]
    min_samples_split = [2, 10, 20]
    max_features = ['log2','sqrt']

    # Grid search parameters
    grid = dict(max_depth=max_depth,min_samples_leaf=min_samples_leaf, min_samples_split=min_samples_split, max_features=max_features)
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=rfc, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
    grid_result = grid_search.fit(X_train, y_train)

    #Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

    # Best Model
    best_model = RandomForestClassifier(**grid_result.best_params_)
    best_model.fit(X_train, y_train)
    end_time = time.time()
    print(f"Total time taken to train the model {end_time-start_time} seconds")
    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)
    # Printing the training accuracy
    print(
        "Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train)
    )
    # Printing the testing accuracy
    print(
        "Test accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test)
    )

    # Printing the classification report
    print(classification_report(y_test, y_pred))
    # Printing the confusion matrix
    print(confusion_matrix(y_test,y_pred))
    # Printing precision, recall, fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    # Saving the best model
    with open('tfidf_rf_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)
    
    return best_model

# %%
# Support Vector Machine model
# Function to build and evaluate a Support Vector Machine model
def build_model_SVC(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()
    # Initialization and training a Support Vector Machine model with specified parameters
    svc = SVC(probability=True)
    #define parameters
    C = [0.1, 1, 10]
    gamma_val = ['scale', 'auto']
    kernel_val = ["rbf", "linear", "sigmoid"]

    # Grid search parameters
    grid = dict(C=C, gamma=gamma_val, kernel=kernel_val)
    cv = KFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=svc, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
    grid_result = grid_search.fit(X_train, y_train)
    # best model
    best_model = SVC(**grid_result.best_params_)
    best_model.fit(X_train, y_train)
    end_time = time.time()

    #Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    print(f"Total time taken to train the model {end_time-start_time} seconds")
    
    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)


    # Printing the training accuracy
    print(
        "Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train)
    )
    # Printing the testing accuracy
    print("Testing accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test))

    # Printing the classification report
    print(classification_report(y_test, y_pred))
    # Printing the confusion matrix
    print(confusion_matrix(y_test,y_pred))
    # Calculation of precision, recall and fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    # Saving the best model
    with open('tfidf_svc_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)

    
    return best_model

# %%
# Logistic Regression Model
# Function to build and evaluate a Logistic Regression model
def build_model_LR(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()

    log_reg = LogisticRegression()
    

    #define parameters
    solvers = ['newton-cg','lbfgs','saga'] #Suitable for large datasets
    penalty = ['l2','l1']
    c_values = [100, 10, 1.0, 0.1]
    max_iter = [100, 200, 300]

    #grid_search
    grid = dict(solver = solvers, penalty = penalty, C=c_values, max_iter=max_iter)
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=log_reg, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
    grid_result = grid_search.fit(X_train, y_train)
    

    #Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    #best model
    best_model = LogisticRegression(**grid_result.best_params_)
    best_model.fit(X_train, y_train)
    end_time = time.time()
    print(f"Total time taken to train the model {end_time-start_time} seconds")
    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)
    # Printing the training accuracy
    print(
        "Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train)
    )
    # Printing the testing accuracy
    print("Testing accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test))

    # Printing the classification report
    print(classification_report(y_test, y_pred))  # Evaluating prediction ability
    # Printing the confusion matrix
    print(confusion_matrix(y_test,y_pred))

    # Calculation of precision, recall and fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    # Save best model
    with open('tfidf_lr_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)
    
    return best_model

# %%
# Building KNN model to find the best model and testing
def build_model_KNN(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()
    # Creation of an instance for KNeighborsClassifier model
    knn = KNeighborsClassifier()

    # Define parameters for grid search
    n_neighbors = [3, 5, 7, 9, 11]
    weights = ['uniform', 'distance']
    metric = ['euclidean', 'manhattan', 'minkowski']

    # grid_search
    grid = dict(n_neighbors=n_neighbors, weights=weights, metric=metric)
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=knn, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy', error_score=0)
    grid_result = grid_search.fit(X_train, y_train)

    # Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

    best_model = KNeighborsClassifier(**grid_result.best_params_)
    best_model.fit(X_train, y_train)
    end_time = time.time()
    print(f"Total time taken to train the model {start_time-end_time} seconds")
    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)

    # Evaluation metrics
    print("Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train))
    print("Testing accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test))

    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))

    #Calculation of precision, recall and fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)

    #Save the best knn model
    with open('tfidf_knn_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)

    return best_model

# %%
# MLP (Multilayer Perceptron) model
def build_model_MLP(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()
    # Creation of an instance for MLPClassifier model
    mlp = MLPClassifier(max_iter=1000)

    # Define parameters for grid search
    hidden_layer_sizes = [(50,), (100,), (50,50), (100,50), (100,100)]
    activation = ['tanh', 'relu']
    solver = ['adam', 'sgd']
    alpha = [0.0001, 0.05]
    learning_rate = ['constant','adaptive']

    # grid_search
    grid = dict(hidden_layer_sizes=hidden_layer_sizes, activation=activation, solver=solver, alpha=alpha, learning_rate=learning_rate)
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=mlp, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy', error_score=0)
    grid_result = grid_search.fit(X_train, y_train)

    # Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

    best_model = MLPClassifier(**grid_result.best_params_, max_iter=1000)
    best_model.fit(X_train, y_train)
    end_time = time.time()
    print(f"Total time taken to train the model {start_time-end_time} seconds")
    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)

    # Evaluation metrics
    print("Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train))
    print("Testing accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test))

    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    # Calculation of precision, recall and fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    #Saving the best mlp model
    with open('tfidf_mlp_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)

    return best_model

# %%
# TF-IDF Feature Extraction Function
def transform_tfidf(training, testing, column_name):
    training[column_name] = training[column_name].fillna('')
    testing[column_name] = testing[column_name].fillna('')
    Tfidf = TfidfVectorizer(
        ngram_range=(1, 3), max_features=100, stop_words='english'   
    )
    Tfidf_fit = Tfidf.fit(training[column_name])
    Tfidf_training = Tfidf_fit.transform(training[column_name])  
    Tfidf_training_df = pd.DataFrame(
        Tfidf_training.toarray(), columns=Tfidf.get_feature_names_out()
    )
    Tfidf_testing = Tfidf_fit.transform(testing[column_name]) 
    Tfidf_testing_df = pd.DataFrame(
        Tfidf_testing.toarray(), columns=Tfidf.get_feature_names_out()
    )
    return Tfidf_fit, Tfidf_training_df, Tfidf_testing_df

# %%
# Load training and test sets
# Loading the train data
df_train = pd.read_csv("Dataset1_2Train_new3.csv")
print("...successfully loaded training data")
print("Total length of training data: ", len(df_train))

# Loading the test data
df_test = pd.read_csv("Dataset1_2Test_new3.csv")
print("...successfully loaded testing data")
print("Total length of testing data: ", len(df_test))

# Creation TfIdf features for the training set
tfidf_vect_fit, df_train_tfidf, df_test_tfidf = transform_tfidf(
    df_train, df_test, "final_cleaned_text"
)
print("...successfully created the unstemmed TFIDF data")

# Loading the vectorizer fit on training data into file
with open('tfidf_vect_fit2.pkl', 'wb') as file:
    pickle.dump(tfidf_vect_fit, file)
# Out:
# ...successfully loaded training data
# Total length of training data:  120000
# ...successfully loaded testing data
# Total length of testing data:  29500
# ...successfully created the unstemmed TFIDF data

# %%
#Building LR model to find the best model and testing
tfidf_lr_best_model = build_model_LR(
    df_train_tfidf,
    df_train["label"],
    df_test_tfidf,
    df_test["label"],
    "TFIDF LR",
)
# Out:
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 240 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to 0.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0.976417 (0.001550) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975950 (0.001458) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.976525 (0.001568) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976508 (0.001559) with: {'C': 100, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.976417 (0.001550) with: {'C': 100, 'max_iter': 200, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975950 (0.001458) with: {'C': 100, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.976517 (0.001564) with: {'C': 100, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 200, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 200, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976508 (0.001559) with: {'C': 100, 'max_iter': 200, 'penalty': 'l1', 'solver': 'saga'}
# 0.976417 (0.001550) with: {'C': 100, 'max_iter': 300, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975950 (0.001458) with: {'C': 100, 'max_iter': 300, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.976517 (0.001564) with: {'C': 100, 'max_iter': 300, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 300, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 300, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976517 (0.001551) with: {'C': 100, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# 0.976183 (0.001540) with: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975808 (0.001368) with: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.976225 (0.001542) with: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976517 (0.001553) with: {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.976183 (0.001540) with: {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975808 (0.001368) with: {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.976225 (0.001542) with: {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976533 (0.001567) with: {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'solver': 'saga'}
# 0.976183 (0.001540) with: {'C': 10, 'max_iter': 300, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975808 (0.001368) with: {'C': 10, 'max_iter': 300, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.976225 (0.001542) with: {'C': 10, 'max_iter': 300, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 300, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 300, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976542 (0.001559) with: {'C': 10, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# 0.975433 (0.001663) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975325 (0.001529) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.975475 (0.001693) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976192 (0.001509) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.975433 (0.001663) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975325 (0.001529) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.975475 (0.001693) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976192 (0.001509) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'saga'}
# 0.975433 (0.001663) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975325 (0.001529) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.975475 (0.001693) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.976192 (0.001509) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# 0.973492 (0.001499) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.973467 (0.001500) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.973492 (0.001499) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.974458 (0.001642) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.973492 (0.001499) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.973467 (0.001500) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.973500 (0.001500) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.974458 (0.001642) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'saga'}
# 0.973492 (0.001499) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.973467 (0.001500) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.973500 (0.001500) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.974458 (0.001642) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# Best: 0.976542 using {'C': 10, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# Total time taken to train the model 353.46453738212585 seconds
# Training accuracy of TFIDF LR:  0.9766583333333333
# Testing accuracy of TFIDF LR:  0.978
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24000
#            1       0.97      0.91      0.94      5500
#
#     accuracy                           0.98     29500
#    macro avg       0.97      0.95      0.96     29500
# weighted avg       0.98      0.98      0.98     29500
#
# [[23821   179]
#  [  470  5030]]
# tn: 23821
# fp: 179
# fn: 470
# tp: 5030
# Precision: 0.9656363985409867
# Recall: 0.9145454545454546
# FScore: 0.9393967690727424
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
tfidf_knn_best_model = build_model_KNN(
    df_train_tfidf,
    df_train["label"],
    df_test_tfidf,
    df_test["label"],
    "TFIDF KNN",
)
# Out:
# 0.916200 (0.002757) with: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.920833 (0.003137) with: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# 0.923742 (0.003083) with: {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.929392 (0.003097) with: {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.925875 (0.002032) with: {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.932500 (0.001920) with: {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'distance'}
# 0.929583 (0.003793) with: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.937367 (0.003473) with: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
# 0.929192 (0.003990) with: {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'uniform'}
# 0.937817 (0.003657) with: {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'distance'}
# 0.914300 (0.002899) with: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.920417 (0.003035) with: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# 0.920675 (0.003230) with: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.928792 (0.003179) with: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.921733 (0.002552) with: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.932092 (0.002166) with: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# 0.925408 (0.003870) with: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.936967 (0.003777) with: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
# 0.924842 (0.004139) with: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'uniform'}
# 0.937342 (0.003878) with: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}
# 0.916200 (0.002757) with: {'metric': 'minkowski', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.920833 (0.003137) with: {'metric': 'minkowski', 'n_neighbors': 3, 'weights': 'distance'}
# 0.923742 (0.003083) with: {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.929392 (0.003097) with: {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.925875 (0.002032) with: {'metric': 'minkowski', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.932500 (0.001920) with: {'metric': 'minkowski', 'n_neighbors': 7, 'weights': 'distance'}
# 0.929583 (0.003793) with: {'metric': 'minkowski', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.937367 (0.003473) with: {'metric': 'minkowski', 'n_neighbors': 9, 'weights': 'distance'}
# 0.929192 (0.003990) with: {'metric': 'minkowski', 'n_neighbors': 11, 'weights': 'uniform'}
# 0.937817 (0.003657) with: {'metric': 'minkowski', 'n_neighbors': 11, 'weights': 'distance'}
# Best: 0.937817 using {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'distance'}
# Total time taken to train the model -854.1897361278534 seconds
# Training accuracy of TFIDF KNN:  0.9439166666666666
# Testing accuracy of TFIDF KNN:  0.9375254237288135
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     24000
#            1       0.76      0.98      0.85      5500
#
#     accuracy                           0.94     29500
#    macro avg       0.88      0.95      0.91     29500
# weighted avg       0.95      0.94      0.94     29500
#
# [[22290  1710]
#  [  133  5367]]
# tn: 22290
# fp: 1710
# fn: 133
# tp: 5367
# Precision: 0.758372191606613
# Recall: 0.9758181818181818
# FScore: 0.853462669953089

# %%
tfidf_mlp_best_model = build_model_MLP(
    df_train_tfidf,
    df_train["label"],
    df_test_tfidf,
    df_test["label"],
    "TFIDF MLP",
)
# Out:
# 0.982625 (0.001246) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.974150 (0.001509) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.983242 (0.001372) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.974333 (0.001669) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.982217 (0.002176) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.974125 (0.001552) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.982192 (0.002687) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.974250 (0.001763) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.983600 (0.001076) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975567 (0.001513) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.983425 (0.001541) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975575 (0.001512) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.983275 (0.001141) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975600 (0.001479) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.983392 (0.001364) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975625 (0.001513) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.983525 (0.001228) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975475 (0.001520) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.983867 (0.001267) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975625 (0.001585) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.975267 (0.001813) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.974033 (0.001449) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.975142 (0.001641) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.974158 (0.001590) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.975250 (0.001706) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.974125 (0.001481) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.975300 (0.001674) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.974133 (0.001533) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.975883 (0.001514) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975583 (0.001612) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.975725 (0.001586) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975583 (0.001555) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.975975 (0.001892) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975667 (0.001486) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.976075 (0.001516) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975592 (0.001633) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.975875 (0.001653) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975600 (0.001710) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.975992 (0.001631) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975733 (0.001558) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.982967 (0.001109) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.974283 (0.001601) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.982967 (0.001157) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.974500 (0.001571) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.983350 (0.001391) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.974283 (0.001606) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.983417 (0.001224) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.974233 (0.001671) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.983350 (0.001400) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975825 (0.001605) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.983308 (0.001422) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975800 (0.001417) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.983633 (0.001275) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.976092 (0.001560) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.983617 (0.001441) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975883 (0.001477) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.983825 (0.001475) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975975 (0.001536) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.983392 (0.001340) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.976225 (0.001416) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.976433 (0.001558) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.974000 (0.001587) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.976208 (0.001648) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.974100 (0.001630) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.977642 (0.001485) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.974100 (0.001593) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.977567 (0.001391) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.974158 (0.001561) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.981442 (0.001354) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.975700 (0.001597) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.981483 (0.001231) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.975758 (0.001688) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.982108 (0.000890) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.976208 (0.001650) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.982042 (0.001048) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.976050 (0.001710) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.982033 (0.001118) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.976425 (0.001672) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.981925 (0.001471) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.976192 (0.001492) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# Best: 0.983867 using {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# Total time taken to train the model -5573.408423900604 seconds
# Training accuracy of TFIDF MLP:  0.9884083333333333
# Testing accuracy of TFIDF MLP:  0.985593220338983
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     24000
#            1       0.98      0.94      0.96      5500
#
#     accuracy                           0.99     29500
#    macro avg       0.98      0.97      0.98     29500
# weighted avg       0.99      0.99      0.99     29500
#
# [[23910    90]
#  [  335  5165]]
# tn: 23910
# fp: 90
# fn: 335
# tp: 5165
# Precision: 0.9828734538534729
# Recall: 0.9390909090909091
# FScore: 0.9604834960483496

# %%
tfidf_svc_best_model = build_model_SVC(
    df_train_tfidf,
    df_train["label"],
    df_test_tfidf,
    df_test["label"],
    "TFIDF SVC",
)
# Out:
# 0.977533 (0.000900) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.974108 (0.000947) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 0.956583 (0.003684) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.963175 (0.001452) with: {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.974108 (0.000947) with: {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 0.960258 (0.001562) with: {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 0.982083 (0.000914) with: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.975525 (0.000990) with: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 0.951292 (0.004577) with: {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.972258 (0.001097) with: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.975525 (0.000990) with: {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 0.970050 (0.001116) with: {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 0.983892 (0.000707) with: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.975858 (0.000913) with: {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 0.951083 (0.002846) with: {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.975042 (0.000908) with: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.975858 (0.000913) with: {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 0.974100 (0.000948) with: {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# Best: 0.983892 using {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Total time taken to train the model 36160.01190948486 seconds
# Training accuracy of TFIDF SVC:  0.9878083333333333
# Testing accuracy of TFIDF SVC:  0.9852203389830508
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     24000
#            1       0.98      0.94      0.96      5500
#
#     accuracy                           0.99     29500
#    macro avg       0.98      0.97      0.98     29500
# weighted avg       0.99      0.99      0.99     29500
#
# [[23894   106]
#  [  330  5170]]
# tn: 23894
# fp: 106
# fn: 330
# tp: 5170
# Precision: 0.9799090219863533
# Recall: 0.94
# FScore: 0.959539717891611

# %%
#Building RF model to find the best model and testing
tfidf_rf_best_model = build_model_RF(
    df_train_tfidf,
    df_train["label"],
    df_test_tfidf,
    df_test["label"],
    "TFIDF RF",
)
# Out:
# 0.882017 (0.013246) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.888367 (0.006894) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.883942 (0.007895) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.887375 (0.005049) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.887100 (0.008081) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.886617 (0.008423) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.893217 (0.010402) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.888250 (0.009960) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.884317 (0.006349) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.920475 (0.005012) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.921125 (0.004026) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.922392 (0.003708) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.921458 (0.005070) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.918750 (0.004486) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.917067 (0.004268) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.921625 (0.003454) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919567 (0.003862) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.922075 (0.003346) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.930742 (0.003467) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.932183 (0.003536) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.934808 (0.004187) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933742 (0.002787) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.931342 (0.003989) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.930317 (0.004934) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.930433 (0.006542) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.933417 (0.001900) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.933758 (0.006754) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.950583 (0.003936) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.953450 (0.004511) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.950383 (0.006587) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.950150 (0.003713) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.952775 (0.006004) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.948633 (0.005281) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.952342 (0.005908) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.949108 (0.006303) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.951142 (0.005539) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.967058 (0.003330) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.967617 (0.003591) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.966675 (0.003471) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.967308 (0.002397) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.967517 (0.003284) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.965900 (0.004285) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.966983 (0.002929) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.965208 (0.004114) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.966525 (0.001361) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.972175 (0.002091) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.972050 (0.001799) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.971825 (0.001492) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.972250 (0.001782) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.971933 (0.001987) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.972150 (0.001732) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.972083 (0.001908) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.972150 (0.001413) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.971842 (0.001927) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.984275 (0.001279) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.983833 (0.001259) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.983392 (0.001192) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.980233 (0.001416) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.980367 (0.001601) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.980200 (0.001446) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.978775 (0.001372) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.978708 (0.001449) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.978717 (0.001505) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.984008 (0.001107) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.983658 (0.001113) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.983150 (0.001025) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.980650 (0.001477) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.980633 (0.001543) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.980533 (0.001495) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.978783 (0.001626) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.978833 (0.001496) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.978758 (0.001639) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20}
# Best: 0.984275 using {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# Total time taken to train the model 661.4721312522888 seconds
# Training accuracy of TFIDF RF:  0.9887333333333334
# Test accuracy of TFIDF RF:  0.9857966101694915
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     24000
#            1       0.98      0.94      0.96      5500
#
#     accuracy                           0.99     29500
#    macro avg       0.98      0.97      0.98     29500
# weighted avg       0.99      0.99      0.99     29500
#
# [[23908    92]
#  [  327  5173]]
# tn: 23908
# fp: 92
# fn: 327
# tp: 5173
# Precision: 0.9825261158594492
# Recall: 0.9405454545454546
# FScore: 0.9610775661867162

# %%
# Loading Dataset 2 for testing
df_test1 = pd.read_csv("Dataset2_2Train_new2.csv", encoding='latin1')
df_test2 = pd.read_csv("Dataset2_2Test_new2.csv", encoding='latin1')
df_test = pd.concat([df_test1, df_test2], axis=0, ignore_index=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)
# final_cleaned_text contains the text after level 1 and 2 preprocessing
X_test1 = df_test['final_cleaned_text'].values
y_test = df_test['label'].values

# %%
# Testing the best LR model with Dataset 2
def check_best_model_LR(X_test1, y_test, tfidf_lr_best_model, tfidf_vect_fit):
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = tfidf_vect_fit.transform(X_test1)
    y_pred = tfidf_lr_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
    result_df = pd.DataFrame({
        'X_test': X_test1,
        'y_test': y_test,
        'y_pred': y_pred
    })
    actual_spam = result_df[(result_df['y_test'] == 1) & (result_df['y_pred'] == 1)]
    misclassified_spam = result_df[(result_df['y_test'] == 1) & (result_df['y_pred'] == 0)]
    return misclassified_spam, actual_spam
start_time = time.time()
misclassified_spam, actual_spam = check_best_model_LR(X_test1, y_test, tfidf_lr_best_model, tfidf_vect_fit)
end_time = time.time()
print(f"Total time taken to test the model {end_time-start_time} seconds")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     22458
#            1       0.90      0.72      0.80      4491
#
#     accuracy                           0.94     26949
#    macro avg       0.93      0.85      0.88     26949
# weighted avg       0.94      0.94      0.94     26949
#
# [[22118   340]
#  [ 1271  3220]]
# Precision: 0.9044943820224719
# Recall: 0.7169895346248052
# FScore: 0.7999006334616817
# Testing Accuracy: 0.9402204163419793
# Total time taken to test the model 6.113078832626343 seconds
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# Testing the best RF model with Dataset 2
def check_best_model_RF(X_test1, y_test, tfidf_rf_best_model, tfidf_vect_fit):
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = tfidf_vect_fit.transform(X_test1)
    y_pred = tfidf_rf_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
start_time = time.time()
check_best_model_RF(X_test1, y_test, tfidf_rf_best_model, tfidf_vect_fit)
end_time = time.time()
print(f"Total time taken to test the model {end_time-start_time} seconds")
# Out:
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     22458
#            1       0.93      0.74      0.83      4491
#
#     accuracy                           0.95     26949
#    macro avg       0.94      0.87      0.90     26949
# weighted avg       0.95      0.95      0.95     26949
#
# [[22225   233]
#  [ 1163  3328]]
# Precision: 0.9345689413086212
# Recall: 0.74103763081719
# FScore: 0.8266269249875807
# Testing Accuracy: 0.948198448922038
# Total time taken to test the model 6.305509090423584 seconds

# %%
# Testing the best KNN model with Dataset 2
def check_best_model_KNN(X_test1, y_test, tfidf_knn_best_model, tfidf_vect_fit):
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = tfidf_vect_fit.transform(X_test1)
    y_pred = tfidf_knn_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
start_time = time.time()
check_best_model_KNN(X_test1, y_test, tfidf_knn_best_model, tfidf_vect_fit)
end_time = time.time()
print(f"Total time taken to test the model {end_time-start_time} seconds")
# Out:
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94     22458
#            1       0.65      0.79      0.72      4491
#
#     accuracy                           0.90     26949
#    macro avg       0.81      0.85      0.83     26949
# weighted avg       0.91      0.90      0.90     26949
#
# [[20580  1878]
#  [  943  3548]]
# Precision: 0.6538886841135274
# Recall: 0.7900244934313071
# FScore: 0.7155389734798829
# Testing Accuracy: 0.8953207911239749
# Total time taken to test the model 10.359087705612183 seconds

# %%
# Testing the best MLP model with Dataset 2
def check_best_model_MLP(X_test1, y_test, tfidf_mlp_best_model, tfidf_vect_fit):
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = tfidf_vect_fit.transform(X_test1)
    y_pred = tfidf_mlp_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
start_time = time.time()
check_best_model_MLP(X_test1, y_test, tfidf_mlp_best_model, tfidf_vect_fit)
end_time = time.time()
print(f"Total time taken to test the model {end_time-start_time} seconds")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     22458
#            1       0.89      0.75      0.82      4491
#
#     accuracy                           0.94     26949
#    macro avg       0.92      0.87      0.89     26949
# weighted avg       0.94      0.94      0.94     26949
#
# [[22050   408]
#  [ 1111  3380]]
# Precision: 0.8922914466737064
# Recall: 0.7526163437987086
# FScore: 0.8165237347505737
# Testing Accuracy: 0.9436342721436788
# Total time taken to test the model 6.116954326629639 seconds
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(

# %%
# Testing the best SVC model with Dataset 2
def check_best_model_SVC(X_test1, y_test, tfidf_svc_best_model,tfidf_vect_fit):
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = tfidf_vect_fit.transform(X_test1).toarray()
    y_pred = tfidf_svc_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
start_time = time.time()
check_best_model_SVC(X_test1, y_test, tfidf_svc_best_model, tfidf_vect_fit)
end_time= time.time()
print(f"Total time taken to test the model {end_time-start_time} seconds")
# Out:
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     22458
#            1       0.89      0.75      0.81      4491
#
#     accuracy                           0.94     26949
#    macro avg       0.92      0.86      0.89     26949
# weighted avg       0.94      0.94      0.94     26949
#
# [[22033   425]
#  [ 1132  3359]]
# Precision: 0.8876849894291755
# Recall: 0.7479403250946337
# FScore: 0.8118429003021148
# Testing Accuracy: 0.9422242012690638
# Total time taken to test the model 17.614754915237427 seconds

# %%
 # Higher DPI ROC Plots for better resolution
model_files = [
    ('tfidf_lr_model2.pkl', 'Logistic Regression'),
    ('tfidf_rf_model2.pkl', 'Random Forest'),
    ('tfidf_svc_model2.pkl', 'SVM'),
    ('tfidf_knn_model2.pkl', 'K Nearest Neighbors'),
    ('tfidf_mlp_model2.pkl', 'Multi-Layer Perceptron')
]
df_test_tfidf.columns = df_test_tfidf.columns.astype(str)
plt.figure(figsize=(12, 10), dpi=300) 

for file, label in model_files:
    with open(file, 'rb') as f:
        model = pickle.load(f)
    try:
        y_proba = model.predict_proba(df_test_tfidf)[:, 1]
    except AttributeError:
        y_proba = model.decision_function(df_test_tfidf)

    fpr, tpr, _ = roc_curve(y_test, y_proba)
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'{label} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Word2Vec (Dataset 2)')
plt.legend(loc="lower right")
plt.grid(True)

# Save high-resolution version
plt.savefig("roc_curves_tfidf_dataset2.png", dpi=300, bbox_inches='tight')
plt.show()
