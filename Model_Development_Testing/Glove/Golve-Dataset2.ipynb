# %%
# Installation of all the required libraries
#!pip install scikit-learn
#!pip install tensorflow
#!pip install accelerate -U  
#!pip install transformers[torch]  
#!pip install torch          
#!pip install openpyxl

# %%
# Importing all the necessary libraries
import sklearn
import pandas as pd
import pickle
import time
import numpy as np
import matplotlib.pyplot as plt
from numpy import mean
#performance and evaluation of test data using metrics - accuracy score, confusion matrix, and classification report.
from sklearn.metrics import classification_report, roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve,auc
#Classiifers - Logistic Regression, SVC, Random Forest, KNN and MLP are trained on the training data.
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.neural_network import MLPClassifier  
from sklearn.model_selection import StratifiedKFold, GridSearchCV, KFold, cross_val_score

# %%
# Random Forest Model
# Function to build and evaluate a Random Forest model
def build_model_RF(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()
    rfc = RandomForestClassifier()
    #parameters
    max_depth = [3, 5, 10, None]
    min_samples_leaf = [1, 5, 10]
    min_samples_split = [2, 10, 20]
    max_features = ['log2','sqrt']

    # Grid search parameters
    grid = dict(max_depth=max_depth,min_samples_leaf=min_samples_leaf, min_samples_split=min_samples_split, max_features=max_features)
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=rfc, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
    grid_result = grid_search.fit(X_train, y_train)

    #Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

    # Best Model
    best_model = RandomForestClassifier(**grid_result.best_params_)
    best_model.fit(X_train, y_train)
    
    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)
    # Printing the training accuracy
    print(
        "Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train)
    )
    # Printing the testing accuracy
    print(
        "Test accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test)
    )

    #classification report
    print(classification_report(y_test, y_pred))
    # confusion matrix
    print(confusion_matrix(y_test,y_pred))
    # precision, recall, fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    # Saving the best model
    with open('glove_rf_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
    return best_model

# %%
# Support Vector Machine model
# Function to build and evaluate a Support Vector Machine model
def build_model_SVC(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()
    svc = SVC()
    #define parameters
    C = [0.1, 1, 10]
    gamma_val = ['scale', 'auto']
    kernel_val = ["rbf", "linear", "sigmoid"]

    # Grid search parameters
    grid = dict(C=C, gamma=gamma_val, kernel=kernel_val)
    cv = KFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=svc, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
    grid_result = grid_search.fit(X_train, y_train)
    # best model
    best_model = SVC(**grid_result.best_params_)
    best_model.fit(X_train, y_train)
    #Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)


    # training accuracy
    print(
        "Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train)
    )
    # testing accuracy
    print("Testing accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test))

    # classification report
    print(classification_report(y_test, y_pred))
    # confusion matrix
    print(confusion_matrix(y_test,y_pred))
    # precision, recall and fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    # Saving the best model
    with open('glove_svc_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
    
    return best_model

# %%
# Logistic Regression Model
# Function to build and evaluate a Logistic Regression model
def build_model_LR(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()
    log_reg = LogisticRegression()
    
    #define parameters
    solvers = ['newton-cg','lbfgs','saga'] #Suitable for large datasets
    penalty = ['l2','l1']
    c_values = [100, 10, 1.0, 0.1]
    max_iter = [100, 200, 300]

    #grid_search
    grid = dict(solver = solvers, penalty = penalty, C=c_values, max_iter=max_iter)
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=log_reg, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
    grid_result = grid_search.fit(X_train, y_train)
    

    #Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    #best model
    best_model = LogisticRegression(**grid_result.best_params_)
    best_model.fit(X_train, y_train)
    
    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)
    # training accuracy
    print(
        "Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train)
    )
    # testing accuracy
    print("Testing accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test))

    # classification report
    print(classification_report(y_test, y_pred))  # Evaluating prediction ability
    # confusion matrix
    print(confusion_matrix(y_test,y_pred))

    # precision, recall and fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    # Save best model
    with open('glove_lr_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
    return best_model

# %%
# Building KNN model to find the best model and testing
def build_model_KNN(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()
    knn = KNeighborsClassifier()

    # Define parameters for grid search
    n_neighbors = [3, 5, 7, 9, 11]
    weights = ['uniform', 'distance']
    metric = ['euclidean', 'manhattan', 'minkowski']

    # grid_search
    grid = dict(n_neighbors=n_neighbors, weights=weights, metric=metric)
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=knn, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy', error_score=0)
    grid_result = grid_search.fit(X_train, y_train)

    # Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

    best_model = KNeighborsClassifier(**grid_result.best_params_)
    best_model.fit(X_train, y_train)

    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)

    # Evaluation metrics
    print("Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train))
    print("Testing accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test))

    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))

    #precision, recall and fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()

    #Save the best knn model
    with open('glove_knn_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
    return best_model

# %%
# MLP (Multilayer Perceptron) model
# Function to build and evaluate a MLP model
def build_model_MLP(X_train, y_train, X_test, y_test, name_of_test):
    start_time = time.time()
    # Creation of an instance for MLPClassifier model
    mlp = MLPClassifier(max_iter=1000)

    # Define parameters for grid search
    hidden_layer_sizes = [(50,), (100,), (50,50), (100,50), (100,100)]
    activation = ['tanh', 'relu']
    solver = ['adam', 'sgd']
    alpha = [0.0001, 0.05]
    learning_rate = ['constant','adaptive']

    # grid_search
    grid = dict(hidden_layer_sizes=hidden_layer_sizes, activation=activation, solver=solver, alpha=alpha, learning_rate=learning_rate)
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    grid_search = GridSearchCV(estimator=mlp, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy', error_score=0)
    grid_result = grid_search.fit(X_train, y_train)

    # Results
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

    best_model = MLPClassifier(**grid_result.best_params_, max_iter=1000)
    best_model.fit(X_train, y_train)

    # Prediction of labels for the test set
    y_pred = best_model.predict(X_test)

    # Evaluation metrics
    print("Training accuracy of " + name_of_test + ": ", best_model.score(X_train, y_train))
    print("Testing accuracy of " + name_of_test + ": ", best_model.score(X_test, y_test))

    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    # Calculation of precision, recall and fscore
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn:",tn)
    print("fp:",fp)
    print("fn:",fn)
    print("tp:",tp)
    
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    #Saving the best mlp model
    with open('glove_mlp_model2.pkl', 'wb') as file:
        pickle.dump(best_model, file)
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
    return best_model

# %%
# Loading the glove model from glove_6B_100D.txt file
def load_glove_model(glove_file):
    print("Loading Glove Model")
    glove_model = {}
    with open(glove_file, 'r', encoding="utf8") as f:
        for line in f:
            split_line = line.split()
            word = split_line[0]
            embedding = np.array([float(val) for val in split_line[1:]])
            glove_model[word] = embedding
    print("Glove model loaded with {} words.".format(len(glove_model)))
    return glove_model

# %%
#Similar to W2V just that the model needs to be loaded manually
def transform_glove(training, testing, column_name, glove_file_path, vector_size=100):
    # Replace NaN values with an empty string
    training[column_name] = training[column_name].fillna('')
    testing[column_name] = testing[column_name].fillna('')

    # Tokenize the training and testing data
    training_tokens = [text.split() for text in training[column_name]]
    testing_tokens = [text.split() for text in testing[column_name]]

    # Load GloVe vectors for the words in the training data
    vocab = {word for tokens in training_tokens for word in tokens}  # Unique words in training data
    glove_fit = {}

    with open(glove_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.split()
            word = parts[0]
            if word in vocab:  # Load only words from the training vocabulary
                vector = np.array(parts[1:], dtype='float32')
                glove_fit[word] = vector

    print(f"Created glove_fit with {len(glove_fit)} word vectors.")

    # Function to compute embeddings using glove_fit
    def get_glove_embedding(words):
        # Compute the mean vector for words present in glove_fit
        embedding = np.mean(
            [glove_fit[word] for word in words if word in glove_fit] or [np.zeros(vector_size)],
            axis=0
        )
        return embedding

    # Create embeddings for training and testing datasets
    training_embeddings = np.array([get_glove_embedding(words) for words in training_tokens])
    training_embeddings_df = pd.DataFrame(training_embeddings)

    testing_embeddings = np.array([get_glove_embedding(words) for words in testing_tokens])
    testing_embeddings_df = pd.DataFrame(testing_embeddings)

    return glove_fit, training_embeddings_df, testing_embeddings_df

# %%
# Load train data
df_train = pd.read_csv("Dataset1_2Train_new3.csv")
df_train = df_train.sample(frac=1).reset_index(drop=True)
print("Total length of training data: ", len(df_train))
df_test = pd.read_csv("Dataset1_2Test_new3.csv",  encoding='latin1')
df_test = df_test.sample(frac=1).reset_index(drop=True)
print("Total length of testing data: ", len(df_test))

# Create Glove features for training set
glove_fit, df_train_glove_unstem, df_test_glove_unstem = transform_glove(
    df_train, df_test, "final_cleaned_text", "glove.6B.100d.txt"
)
print("...successfully created the unstemmed GloVe data")

# Loading the vectorizer fit on training data into file
with open('glove_vect_fit2.pkl', 'wb') as file:
    pickle.dump(glove_fit, file)
# Out:
# Total length of training data:  120000
# Total length of testing data:  29500
# Created glove_fit with 41581 word vectors.
# ...successfully created the unstemmed GloVe data

# %%
#Building LR model to find the best model and testing
glove_lr_best_model = build_model_LR(
    df_train_glove_unstem,
    df_train["label"],
    df_test_glove_unstem,
    df_test["label"],
    "TFIDF Unstemmed",
)
# Out:
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 240 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to 0.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# 0.979808 (0.001499) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.979125 (0.001660) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979783 (0.001509) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979792 (0.001476) with: {'C': 100, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.979808 (0.001499) with: {'C': 100, 'max_iter': 200, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.979125 (0.001660) with: {'C': 100, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979792 (0.001493) with: {'C': 100, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 200, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 200, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979767 (0.001483) with: {'C': 100, 'max_iter': 200, 'penalty': 'l1', 'solver': 'saga'}
# 0.979808 (0.001499) with: {'C': 100, 'max_iter': 300, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.979125 (0.001660) with: {'C': 100, 'max_iter': 300, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979792 (0.001493) with: {'C': 100, 'max_iter': 300, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 300, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 100, 'max_iter': 300, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979767 (0.001483) with: {'C': 100, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# 0.979633 (0.001485) with: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.979175 (0.001497) with: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979642 (0.001499) with: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979742 (0.001511) with: {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.979633 (0.001485) with: {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.979175 (0.001497) with: {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979642 (0.001499) with: {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979775 (0.001508) with: {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'solver': 'saga'}
# 0.979633 (0.001485) with: {'C': 10, 'max_iter': 300, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.979175 (0.001497) with: {'C': 10, 'max_iter': 300, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979642 (0.001499) with: {'C': 10, 'max_iter': 300, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 300, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 10, 'max_iter': 300, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979775 (0.001508) with: {'C': 10, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# 0.979192 (0.001515) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.978858 (0.001503) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979183 (0.001483) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979558 (0.001477) with: {'C': 1.0, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.979192 (0.001515) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.978858 (0.001503) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979183 (0.001483) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979567 (0.001492) with: {'C': 1.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'saga'}
# 0.979192 (0.001515) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.978858 (0.001503) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.979183 (0.001483) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.979567 (0.001492) with: {'C': 1.0, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# 0.975567 (0.001278) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975500 (0.001295) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.975558 (0.001318) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.977633 (0.001391) with: {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.975567 (0.001278) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975500 (0.001295) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.975567 (0.001312) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.977642 (0.001393) with: {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'saga'}
# 0.975567 (0.001278) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.975500 (0.001295) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.975567 (0.001312) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l2', 'solver': 'saga'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.977642 (0.001393) with: {'C': 0.1, 'max_iter': 300, 'penalty': 'l1', 'solver': 'saga'}
# Best: 0.979808 using {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# Training accuracy of TFIDF Unstemmed:  0.980225
# Testing accuracy of TFIDF Unstemmed:  0.9809830508474576
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     24000
#            1       0.95      0.95      0.95      5500
#
#     accuracy                           0.98     29500
#    macro avg       0.97      0.97      0.97     29500
# weighted avg       0.98      0.98      0.98     29500
#
# [[23734   266]
#  [  295  5205]]
# tn: 23734
# fp: 266
# fn: 295
# tp: 5205
# Precision: 0.9513800036556388
# Recall: 0.9463636363636364
# FScore: 0.9488651900464862
# The time required for training is 292.6926534175873 seconds

# %%
#Building KNN model to find the best model and testing
glove_knn_best_model = build_model_KNN(
    df_train_glove_unstem,
    df_train["label"],
    df_test_glove_unstem,
    df_test["label"],
    "TFIDF Unstemmed",
)
# Out:
# 0.989075 (0.000516) with: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.990842 (0.000397) with: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# 0.987625 (0.000762) with: {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.989842 (0.000471) with: {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.986542 (0.001012) with: {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.989067 (0.000569) with: {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'distance'}
# 0.985683 (0.000864) with: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.988550 (0.000526) with: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
# 0.985025 (0.000957) with: {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'uniform'}
# 0.988150 (0.000634) with: {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'distance'}
# 0.989133 (0.000759) with: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.990867 (0.000425) with: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# 0.987308 (0.001027) with: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.989683 (0.000722) with: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.986433 (0.001077) with: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.989142 (0.000635) with: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# 0.985650 (0.000998) with: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.988483 (0.000670) with: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
# 0.984892 (0.001194) with: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'uniform'}
# 0.987975 (0.000736) with: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}
# 0.989075 (0.000516) with: {'metric': 'minkowski', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.990842 (0.000397) with: {'metric': 'minkowski', 'n_neighbors': 3, 'weights': 'distance'}
# 0.987625 (0.000762) with: {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.989842 (0.000471) with: {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.986542 (0.001012) with: {'metric': 'minkowski', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.989067 (0.000569) with: {'metric': 'minkowski', 'n_neighbors': 7, 'weights': 'distance'}
# 0.985683 (0.000864) with: {'metric': 'minkowski', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.988550 (0.000526) with: {'metric': 'minkowski', 'n_neighbors': 9, 'weights': 'distance'}
# 0.985025 (0.000957) with: {'metric': 'minkowski', 'n_neighbors': 11, 'weights': 'uniform'}
# 0.988150 (0.000634) with: {'metric': 'minkowski', 'n_neighbors': 11, 'weights': 'distance'}
# Best: 0.990867 using {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# Training accuracy of TFIDF Unstemmed:  0.9999916666666666
# Testing accuracy of TFIDF Unstemmed:  0.9928474576271187
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     24000
#            1       1.00      0.96      0.98      5500
#
#     accuracy                           0.99     29500
#    macro avg       0.99      0.98      0.99     29500
# weighted avg       0.99      0.99      0.99     29500
#
# [[23986    14]
#  [  197  5303]]
# tn: 23986
# fp: 14
# fn: 197
# tp: 5303
# Precision: 0.9973669362422418
# Recall: 0.9641818181818181
# FScore: 0.9804936673754275
# The time required for training is 742.0405766963959 seconds

# %%
#Building MLP model to find the best model and testing
glove_mlp_best_model = build_model_MLP(
    df_train_glove_unstem,
    df_train["label"],
    df_test_glove_unstem,
    df_test["label"],
    "TFIDF Unstemmed",
)
# Out:
# 0.994475 (0.000887) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.980175 (0.000894) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994675 (0.000520) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.980283 (0.001152) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.994592 (0.000794) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.979550 (0.001478) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994933 (0.000559) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.979958 (0.001018) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.994517 (0.000839) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.985500 (0.002020) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994333 (0.000822) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.985400 (0.001442) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.994675 (0.000565) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.984558 (0.001241) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994650 (0.000674) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.985042 (0.001005) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.994583 (0.000823) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.984975 (0.001855) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994375 (0.000640) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.985442 (0.001301) with: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.985958 (0.000679) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.979125 (0.001377) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.985567 (0.001155) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.979317 (0.000937) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.986092 (0.000790) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.978983 (0.001051) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.985825 (0.000789) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.979175 (0.001313) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.988608 (0.001273) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.984750 (0.000966) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.988975 (0.001287) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.984867 (0.000842) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.989150 (0.001086) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.984392 (0.000963) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.988667 (0.001017) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.984317 (0.000835) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.988733 (0.000790) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.985083 (0.001096) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.988783 (0.001082) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.984817 (0.001117) with: {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.994775 (0.000489) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.984292 (0.000988) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994700 (0.000887) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.984367 (0.001206) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.995042 (0.000675) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.984650 (0.001033) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994950 (0.000701) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.984700 (0.001127) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.994417 (0.001248) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.990667 (0.001185) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994783 (0.000545) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.991033 (0.000908) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.994883 (0.000623) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.992400 (0.000477) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994867 (0.000801) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.992142 (0.000845) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.995117 (0.000663) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.992025 (0.000603) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.994925 (0.000753) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.992358 (0.001081) with: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.988658 (0.001339) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.982708 (0.001111) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.988925 (0.000892) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.982933 (0.001164) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.988542 (0.001136) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.983225 (0.000820) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.988783 (0.001149) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.983417 (0.001187) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.992783 (0.001236) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.990150 (0.001199) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.992700 (0.001067) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.989742 (0.001468) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.992558 (0.000885) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.991183 (0.001208) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.992867 (0.001051) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.991275 (0.000832) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.993317 (0.000464) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.991458 (0.000514) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.993008 (0.000636) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.991750 (0.000946) with: {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# Best: 0.995117 using {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'solver': 'adam'}
# Training accuracy of TFIDF Unstemmed:  0.9989166666666667
# Testing accuracy of TFIDF Unstemmed:  0.996406779661017
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     24000
#            1       1.00      0.98      0.99      5500
#
#     accuracy                           1.00     29500
#    macro avg       1.00      0.99      0.99     29500
# weighted avg       1.00      1.00      1.00     29500
#
# [[23985    15]
#  [   91  5409]]
# tn: 23985
# fp: 15
# fn: 91
# tp: 5409
# Precision: 0.9972345132743363
# Recall: 0.9834545454545455
# FScore: 0.990296594653973
# The time required for training is 5712.281285762787 seconds

# %%
#Building RF model to find the best model and testing
glove_rf_best_model = build_model_RF(
    df_train_glove_unstem,
    df_train["label"],
    df_test_glove_unstem,
    df_test["label"],
    "TFIDF Unstemmed",
)
# Out:
# 0.930050 (0.003981) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.929925 (0.003225) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.929925 (0.002757) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.929142 (0.002897) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.929708 (0.003271) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.929758 (0.002332) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.929442 (0.002305) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.930683 (0.002619) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.929342 (0.002662) with: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.940358 (0.001869) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.939975 (0.001893) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.940000 (0.002032) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.940175 (0.001736) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.940158 (0.002025) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.940400 (0.001792) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.940450 (0.002030) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.940083 (0.001740) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.939925 (0.001272) with: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.954792 (0.001534) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.955333 (0.001882) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.955392 (0.001586) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.955600 (0.001553) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.955200 (0.002170) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.955975 (0.001665) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.955125 (0.001916) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.955258 (0.001460) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.955192 (0.001470) with: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.958558 (0.001388) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.958708 (0.001546) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.958383 (0.001839) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.958667 (0.001448) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.958700 (0.001031) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.958883 (0.001463) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.958583 (0.001565) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.958683 (0.000803) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.958300 (0.001613) with: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.980558 (0.000749) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.980117 (0.000668) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.979658 (0.000854) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.979650 (0.001064) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.979925 (0.000859) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.979383 (0.000815) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.978883 (0.000947) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.979150 (0.001115) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.979000 (0.001048) with: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.982233 (0.000918) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.981725 (0.000945) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.981258 (0.001054) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.981492 (0.001015) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.981208 (0.000937) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.980992 (0.001005) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.980308 (0.000897) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.980308 (0.000842) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.980908 (0.000885) with: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.988375 (0.000521) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.987633 (0.000608) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.986342 (0.000697) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.985883 (0.001053) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.986050 (0.000758) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.984600 (0.000883) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.983467 (0.000730) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.983008 (0.001060) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.983350 (0.001221) with: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.988892 (0.000892) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.988333 (0.000709) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.987150 (0.000728) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.986650 (0.000800) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.986392 (0.000757) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.985617 (0.000820) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.984367 (0.001158) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.984358 (0.000805) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.984425 (0.001019) with: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20}
# Best: 0.988892 using {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# Training accuracy of TFIDF Unstemmed:  0.9999916666666666
# Test accuracy of TFIDF Unstemmed:  0.9918983050847457
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     24000
#            1       0.99      0.96      0.98      5500
#
#     accuracy                           0.99     29500
#    macro avg       0.99      0.98      0.99     29500
# weighted avg       0.99      0.99      0.99     29500
#
# [[23970    30]
#  [  209  5291]]
# tn: 23970
# fp: 30
# fn: 209
# tp: 5291
# Precision: 0.9943619620372111
# Recall: 0.962
# FScore: 0.9779133166990112
# The time required for training is 2919.9473090171814 seconds

# %%
#Building SVC model to find the best model and testing
glove_svc_best_model = build_model_SVC(
    df_train_glove_unstem,
    df_train["label"],
    df_test_glove_unstem,
    df_test["label"],
    "Glove Unstemmed"
)
# Out:
# 0.979292 (0.001061) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.979250 (0.001258) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 0.885483 (0.002206) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.966692 (0.001072) with: {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.979250 (0.001258) with: {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 0.962342 (0.001458) with: {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 0.986467 (0.001197) with: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.980142 (0.001027) with: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 0.873667 (0.021768) with: {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.978308 (0.001252) with: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.980142 (0.001027) with: {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 0.972817 (0.001210) with: {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 0.990783 (0.000858) with: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.980175 (0.000870) with: {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 0.864967 (0.021800) with: {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.982983 (0.001192) with: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.980175 (0.000870) with: {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 0.977992 (0.001260) with: {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# Best: 0.990783 using {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Training accuracy of Glove Unstemmed:  0.9925
# Testing accuracy of Glove Unstemmed:  0.9926101694915255
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     24000
#            1       0.98      0.98      0.98      5500
#
#     accuracy                           0.99     29500
#    macro avg       0.99      0.99      0.99     29500
# weighted avg       0.99      0.99      0.99     29500
#
# [[23913    87]
#  [  131  5369]]
# tn: 23913
# fp: 87
# fn: 131
# tp: 5369
# Precision: 0.9840542521994134
# Recall: 0.9761818181818182
# FScore: 0.9801022270901788
# The time required for training is 9229.617891550064 seconds

# %%
# Loading the dataset for testing
df_test1 = pd.read_csv("Dataset2_2Train_new2.csv")
df_test2 = pd.read_csv("Dataset2_2Test_new2.csv")
df_test = pd.concat([df_test1, df_test2], axis=0, ignore_index=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)

X_test1 = df_test['final_cleaned_text'].values
y_test = df_test['label'].values

# %%
# Function to generate document vectors using GloVe embeddings
def document_vector(glove_model, email):
    words = email.split()
    return np.mean([glove_model[word] for word in words if word in glove_model] or [np.zeros(len(next(iter(glove_model.values()))))], axis=0)
    
# Function to transform test data using GloVe embeddings
def transform_glove(X_test, glove_model):
    X_test_vectors = np.array([document_vector(glove_model, email) for email in X_test])
    return X_test_vectors

# %%
# Testing the best RF model
def check_best_model_RF(X_test1, y_test, glove_rf_best_model, glove_fit):
    start_time = time.time()
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = transform_glove(X_test1,glove_fit)
    y_pred = glove_rf_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
glove_model = load_glove_model('glove.6B.100d.txt')  # Load GloVe vectors
check_best_model_RF(X_test1, y_test, glove_rf_best_model, glove_fit)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95     22458
#            1       0.71      0.80      0.75      4491
#
#     accuracy                           0.91     26949
#    macro avg       0.83      0.87      0.85     26949
# weighted avg       0.92      0.91      0.91     26949
#
# [[20979  1479]
#  [  913  3578]]
# Precision: 0.7075341111330828
# Recall: 0.7967045201514139
# FScore: 0.7494763301214915
# Testing Accuracy: 0.9112397491558129
# The time required for training is 3.2069947719573975 seconds

# %%
# Testing the best LR model
def check_best_model_LR(X_test1, y_test, glove_lr_best_model, glove_fit):
    start_time = time.time()
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = transform_glove(X_test1,glove_fit)
    y_pred = glove_lr_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
check_best_model_LR(X_test1, y_test, glove_lr_best_model, glove_fit)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95     22458
#            1       0.75      0.80      0.77      4491
#
#     accuracy                           0.92     26949
#    macro avg       0.85      0.87      0.86     26949
# weighted avg       0.92      0.92      0.92     26949
#
# [[21273  1185]
#  [  917  3574]]
# Precision: 0.7509981088463963
# Recall: 0.7958138499220664
# FScore: 0.7727567567567567
# Testing Accuracy: 0.9220008163568222
# The time required for training is 2.9681127071380615 seconds

# %%
# Testing the best KNN model
def check_best_model_KNN(X_test1, y_test, glove_knn_best_model, glove_fit):
    start_time = time.time()
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = transform_glove(X_test1, glove_fit)
    y_pred = glove_knn_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
check_best_model_KNN(X_test1, y_test, glove_knn_best_model, glove_fit)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     22458
#            1       0.78      0.69      0.73      4491
#
#     accuracy                           0.92     26949
#    macro avg       0.86      0.82      0.84     26949
# weighted avg       0.91      0.92      0.91     26949
#
# [[21580   878]
#  [ 1398  3093]]
# Precision: 0.7788970032737346
# Recall: 0.6887107548430194
# FScore: 0.7310328527534862
# Testing Accuracy: 0.9155441760362165
# The time required for training is 19.777820348739624 seconds

# %%
# Testing the best MLP model
def check_best_model_MLP(X_test1, y_test, glove_mlp_best_model, glove_fit):
    start_time = time.time()
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = transform_glove(X_test1, glove_fit)
    y_pred = glove_mlp_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
check_best_model_MLP(X_test1, y_test, glove_mlp_best_model, glove_fit)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     22458
#            1       0.79      0.85      0.82      4491
#
#     accuracy                           0.94     26949
#    macro avg       0.88      0.90      0.89     26949
# weighted avg       0.94      0.94      0.94     26949
#
# [[21446  1012]
#  [  659  3832]]
# Precision: 0.7910817506193228
# Recall: 0.8532620797149856
# FScore: 0.8209962506695233
# Testing Accuracy: 0.9379939886452188
# The time required for training is 2.934515953063965 seconds

# %%
# Testing the best SVC model
def check_best_model_SVC(X_test1, y_test, glove_svc_best_model, glove_fit):
    start_time= time.time()
    X_test1 = pd.Series(X_test1)  
    X_test1 = X_test1.fillna('')  
    X_test_feature = transform_glove(X_test1, glove_fit)
    y_pred = glove_svc_best_model.predict(X_test_feature)
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    p = tp/(tp+fp)
    r = tp/(tp+fn)
    fscore = (2*p*r)/(p+r)
    print("Precision:",p)
    print("Recall:",r)
    print("FScore:",fscore)
    accuracy = accuracy_score(y_test, y_pred)
    print("Testing Accuracy:",accuracy)
    fpr,tpr,thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(fpr,tpr) 
    plt.figure()
    plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area=%0.2f)'% roc_auc)
    plt.plot([0,1],[0,1],color='navy',lw=2,linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characterstic (ROC) Curve')
    plt.legend(loc = 'upper right')
    plt.show()
    end_time = time.time()
    print(f"The time required for training is {end_time-start_time} seconds")
check_best_model_SVC(X_test1, y_test, glove_svc_best_model, glove_fit)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     22458
#            1       0.78      0.85      0.82      4491
#
#     accuracy                           0.94     26949
#    macro avg       0.88      0.90      0.89     26949
# weighted avg       0.94      0.94      0.94     26949
#
# [[21407  1051]
#  [  658  3833]]
# Precision: 0.7848075348075348
# Recall: 0.8534847472723224
# FScore: 0.8177066666666668
# Testing Accuracy: 0.9365839177706037
# The time required for training is 12.181989192962646 seconds

# %%
# ROC with Higher DPI for better resolution
model_files = [
    ('glove_lr_model2.pkl', 'Logistic Regression'),
    ('glove_rf_model2.pkl', 'Random Forest'),
    ('glove_svc_model2.pkl', 'SVM'),
    ('glove_knn_model2.pkl', 'K Nearest Neighbors'),
    ('glove_mlp_model2.pkl', 'Multi-Layer Perceptron')
]
df_test_glove_unstem.columns = df_test_glove_unstem.columns.astype(str)
plt.figure(figsize=(12, 10), dpi=300)  

for file, label in model_files:
    with open(file, 'rb') as f:
        model = pickle.load(f)
    try:
        y_proba = model.predict_proba(df_test_glove_unstem)[:, 1]
    except AttributeError:
        y_proba = model.decision_function(df_test_glove_unstem)

    fpr, tpr, _ = roc_curve(y_test, y_proba)
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'{label} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Word2Vec (Dataset 2)')
plt.legend(loc="lower right")
plt.grid(True)

# Save high-resolution version
plt.savefig("roc_curves_glove_dataset2.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\dhareesh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MLPClassifier was fitted without feature names
#   warnings.warn(
